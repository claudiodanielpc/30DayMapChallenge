# %%
import pandas as pd
from keplergl import KeplerGl
from selenium import webdriver

# %%
url="https://archivo.datos.cdmx.gob.mx/fiscalia-general-de-justicia/victimas-en-carpetas-de-investigacion-fgj/victimas_completa_septiembre_2021.csv"

# %%
carpetas=pd.read_csv(url)

# %%
##Limpieza de base de datos
# Columnas a minúsculas
carpetas.columns = carpetas.columns.str.lower()

# %%
##Filtos de datos
carpetas = carpetas[carpetas["año_hecho"] == 2021]
carpetas = carpetas[carpetas["categoria"] == "ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON VIOLENCIA"]

# %%
carpetas[["latitud", "longitud"]] = carpetas[["latitud", "longitud"]].apply(pd.to_numeric)
# Out:
#         idcarpeta  año_inicio  mes_inicio fechainicio  \
# 480568  8828957.0        2021       Enero  02/01/2021
# 480570  8828959.0        2021       Enero  02/01/2021
# 482480  8830969.0        2021       Enero  06/01/2021
# 483697  8832228.0        2021       Enero  08/01/2021
# 483717  8832255.0        2021       Enero  08/01/2021
# ...           ...         ...         ...         ...
# 656511  9024929.0        2021  Septiembre  26/09/2021
# 656937  9025396.0        2021  Septiembre  27/09/2021
# 657281  9025752.0        2021  Septiembre  27/09/2021
# 657599  9026106.0        2021  Septiembre  28/09/2021
# 659642  9028262.0        2021  Septiembre  30/09/2021
#
#                                                    delito  \
# 480568  ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOL...
# 480570  ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOL...
# 482480  ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOL...
# 483697  ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOL...
# ...

# %%
map=KeplerGl(height=800, data={"robos":carpetas},show_docs=False)
map
# Out:
# C:\Users\claud\miniconda3\lib\site-packages\jupyter_client\session.py:716: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# KeplerGl(data={'robos':         idcarpeta  año_inicio  mes_inicio fechainicio  \
# 480568  8828957.0        2021…

# %%
#Obtener y almacenar la configuración del mapa ajustado
config=map.config

#Guardar el mapa con la configuración generada
map=KeplerGl(height=800, data={"DENUE":df},show_docs=False, config=config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3840/4100174146.py in <module>
#       3
#       4 #Guardar el mapa con la configuración generada
# ----> 5 map=KeplerGl(height=800, data={"DENUE":df},show_docs=False, config=config)
#
# NameError: name 'df' is not defined

# %%
#Salvar mapa
map.save_to_html(config=config, file_name='D:\\Documentos\\Github\\30DayMapChallenge\\day_1_points.html')
# Out:
# Map saved to D:\Documentos\Github\30DayMapChallenge\day_1_points.html!

# %%
##Salvar mapa en png con webshot
#Abrir explorador y archivo generado
browser = webdriver.Chrome(executable_path="C:\\Program Files (x86)\\chromedriver.exe")
browser.get('D:\\Documentos\\Github\\30DayMapChallenge\\day_1_points.html')
#Salvar screenshot
browser.save_screenshot('D:\\Documentos\\Github\\30DayMapChallenge\\day_1_points.png')
#Cerrar navegador
browser.quit()
# Out:
# C:\Users\claud\AppData\Local\Temp/ipykernel_3840/1719263925.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path="C:\\Program Files (x86)\\chromedriver.exe")
